# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# Import own libraries 
import os, sys
script_path = os.path.realpath(os.path.dirname("10_on_trajectories"))
os.chdir(script_path)
sys.path.append("..")

from myLibraries.queries import * 
from myLibraries.rawData_queries import *
from myLibraries.events import *
from myLibraries.theoretical_functions import *

# %% [markdown]
# # 2.2.1

# %%
df = get_all_collabs()
df.sample(frac=1)
# Out:
#                  ID  1990  1991  1992  1993  1994  1995  1996  1997  1998  \
# 121520  34168150400     0     0     0     0     0     0     0     0     0
# 117340  26027164100     0     0     0     0     0     0     0     0     0
# 4615     6506299644     0     0     1     1     1     1     3     3     4
# 89440   15128332600     0     0     0     0     0     0     0     0     0
# 192211  56712534700     0     0     0     0     0     0     0     0     0
# ...             ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 194177  56862320800     0     0     0     0     0     0     0     0     0
# 147998  53985410600     0     0     0     0     0     0     0     0     0
# 225615  57202686449     0     0     0     0     0     0     0     0     0
# 133860  36166240400     0     0     0     0     0     0     0     0     0
# 190705  56631516600     0     0     0     0     0     0     0     0     0
#
#         ...  2014  2015  2016  2017  2018  start_year  end_year  \
# 121520  ...     5     5     5     5     5        2008      2008
# 117340  ...     7     7     7     7     7        2011      2011
# 4615    ...    15    24    27    27    27        1992      2018
# 89440   ...    22    22    23    23    23        2000      2016
# 192211  ...     0     0     0     0     6        2018      2018
# ...     ...   ...   ...   ...   ...   ...         ...       ...
# 194177  ...     3     3     3     3     3        2009      2009
# 147998  ...     3     7     7     7     7        2012      2015
# 225615  ...     0     0     0     0     4        2018      2018
# 133860  ...     8     8     9     9     9        2010      2016
# 190705  ...     5     5     5     5     5        2007      2007
#
#         max_hole_size  activity  tot_pubs
# 121520              0         0         1
# 117340              0         0         1
# 4615                6        26        26
# 89440               3        16        16
# 192211              0         0         1
# ...               ...       ...       ...
# 194177              0         0         1
# 147998              1         3         3
# 225615              0         0         1
# 133860              2         6         4
# 190705              0         0         1
#
# [232838 rows x 35 columns]

# %%
plt.figure(figsize=(15, 7), dpi=80)
plt.title("Distribution of authors by starting year")
plt.xlabel("year")
plt.ylabel("# authors")
plt.xticks(rotation=90)

dist = []
for y in get_int_years_event():
    plt.scatter(y, len(df[df["start_year"] == y]))
    
plt.legend(get_int_years_event(), ncol=2)
plt.xticks(get_int_years_event())
plt.show()

# %%
plt.figure(figsize=(15, 7), dpi=80)
plt.title("Distribution of authors by ending year")
plt.xlabel("year")
plt.ylabel("# authors")
plt.xticks(rotation=90)

dist = []
for y in get_int_years_event():
    plt.scatter(y, len(df[df["end_year"] == y]))
    
plt.legend(get_int_years_event(), ncol=2)
plt.xticks(get_int_years_event())
plt.show()

# %% [markdown]
# # 2.2.2

# %%
get_all_collabs_by_hole_size(7, 5, 3)
# Out:
#                  ID  1990  1991  1992  1993  1994  1995  1996  1997  1998  \
# 6        6503847168     0     0     0     0     0     0     0     0     0
# 8        6503849838     0     0     0     0     0     0     0     0     0
# 20       6503858724     0     0     0     0     0     0     0     0     0
# 31       6503866265     0     0     0     0     0     0     0     0     0
# 70       6503889335     0     0     0     0     0     0     0     0     0
# ...             ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 232590  57207536959     0     0     0     0     0     0     0     0     0
# 232623  57207585229     0     0     0     0     0     0     0     0     0
# 232638  57207598135     0     0     0     0     0     0     0     0     0
# 232647  57207604191     0     0     0     0     0     0     0     0     0
# 232654  57207607528     0     0     0     0     0     0     0     0     0
#
#         ...  2014  2015  2016  2017  2018  start_year  end_year  \
# 6       ...    12    12    15    16    21        2004      2018
# 8       ...    13    13    13    32    32        2006      2017
# 20      ...    16    16    16    16    16        1999      2013
# 31      ...    20    20    20    20    20        2002      2012
# 70      ...    16    20    20    25    25        2004      2018
# ...     ...   ...   ...   ...   ...   ...         ...       ...
# 232590  ...    30    30    46    46    47        2009      2018
# 232623  ...     3     3     3     3     3        2009      2016
# 232638  ...    11    11    25    25    27        2009      2018
# 232647  ...    25    25    25    25    25        2009      2016
# 232654  ...    15    15    25    25    30        2009      2018
#
#         max_hole_size  activity  tot_pubs
# 6                   4        14        14
# 8                   7        11         4
# 20                  7        14         5
# 31                  6        10         3
# 70                  3        14        21
# ...               ...       ...       ...
# 232590              4         9        16
# 232623              6         7         4
# 232638              6         9         6
# 232647              4         7        11
# 232654              4         9        18
#
# [36795 rows x 35 columns]

# %% [markdown]
# # 2.2.3

# %%
print("#collaborations ", get_collabs_event(), "\n") # tot #collaborations for each year
print("#authors ",get_auths_event(), "\n") # tot #authors for each year
# Out:
# #collaborations  [1, 5467, 9633, 15710, 23482, 32911, 45320, 63755, 85027, 116972, 142301, 179403, 217612, 290552, 343119, 425267, 498504, 613704, 721423, 869794, 998351, 1179309, 1333411, 1553610, 1731875, 1981635, 2187834, 2506822, 2717599, 3010553]
#
# #authors  [1, 1686, 3188, 4897, 7224, 9608, 12553, 16139, 20187, 24855, 28829, 33715, 38594, 45071, 51364, 58353, 65659, 75197, 85228, 96930, 108579, 120639, 132534, 145313, 158330, 172867, 186757, 201819, 216866, 232836]

# %%
YEARS = get_int_years_event()
COLLABORATION_EVENTS = get_collabs_event()
AUTHOR_EVENTS = get_auths_event()

# %%
plt.figure(figsize=(7, 3), dpi=80)
plt.title("Distribution of new collaborations by year")
plt.xlabel("year")
plt.ylabel("# new_collaborations")
plt.xticks(rotation=90)

prev = 0
asd = []
for y in YEARS:
    if(y!=1990):
        prev = COLLABORATION_EVENTS[YEARS.index(y-1)]
    num_new_collabs = COLLABORATION_EVENTS[YEARS.index(y)] - prev
    asd.append(num_new_collabs)
    plt.scatter(y,  num_new_collabs, label=str(y) + " -> " + str(num_new_collabs))
    
#plt.legend(ncol=2)
plt.xticks(YEARS)
plt.plot(YEARS, asd)
plt.show()

# %%
plt.figure(figsize=(7, 3), dpi=80)
plt.title("Distribution of new authors by year")
plt.xlabel("year")
plt.ylabel("# new_authors")
plt.xticks(rotation=90)

prev = 0
asd = []
for y in YEARS:
    if(y!=1990):
        prev = AUTHOR_EVENTS[YEARS.index(y-1)]
    num_new_auths = AUTHOR_EVENTS[YEARS.index(y)] - prev
    asd.append(num_new_auths)
    plt.scatter(y,  num_new_auths, label=str(y) + " -> " + str(num_new_auths))
    
#plt.legend(ncol=2)
plt.xticks(YEARS)
plt.plot(YEARS, asd)
plt.show()

# %% [markdown]
# # 2.2.6

# %%
plt.figure(figsize=(15, 5), dpi=80)
plt.title("Ratio between the number of new collaborations and new authors")
plt.xlabel("years")
plt.ylabel("#_new_collaborations / #_new_authors")
plt.xticks(rotation=90)

prev_auth = 0
prev_coll = 0
ratios = []
labels = []
for y in YEARS:
    if(y!=1990):
        prev_auth = AUTHOR_EVENTS[YEARS.index(y-1)]      
        prev_coll = COLLABORATION_EVENTS[YEARS.index(y-1)]
    num_new_collabs = COLLABORATION_EVENTS[YEARS.index(y)] - prev_coll
    num_new_auths = AUTHOR_EVENTS[YEARS.index(y)] - prev_auth
    ratio = num_new_collabs/num_new_auths
    labels.append(str(y) + " -> " + str('{:.2f}'.format(ratio)))
    ratios.append(ratio)

plt.plot(YEARS, ratios, color="black")
    
plt.xticks(YEARS)
plt.show()

plt.figure(figsize=(15, 5), dpi=80)
plt.title("Ratio between the number of new collaborations and new authors stretched by new collaboration event")
plt.xlabel("years stretched by collaborations events")
plt.ylabel("#_new_collaborations / #_new_authors")
plt.xticks(rotation=90)

prev_auth = 0
prev_coll = 0
ratios = []
labels = []
for y in YEARS:
    if(y!=1990):
        prev_auth = AUTHOR_EVENTS[YEARS.index(y-1)]      
        prev_coll = COLLABORATION_EVENTS[YEARS.index(y-1)]
    num_new_collabs = COLLABORATION_EVENTS[YEARS.index(y)] - prev_coll
    num_new_auths = AUTHOR_EVENTS[YEARS.index(y)] - prev_auth
    ratio = num_new_collabs/num_new_auths
    
    labels.append(str(y) + " -> " + str('{:.2f}'.format(ratio)))
    ratios.append(ratio)

plt.plot(COLLABORATION_EVENTS[1:], ratios, color="orange")
    
plt.xticks(COLLABORATION_EVENTS[1:], YEARS)
plt.show()


plt.figure(figsize=(15, 5), dpi=80)
plt.title("Ratio between the number of new collaborations and new authors stretched by new author event")
plt.xlabel("years stretched by author events")
plt.ylabel("#_new_collaborations / #_new_authors")
plt.xticks(rotation=90)

prev_auth = 0
prev_coll = 0
ratios = []
labels = []
for y in YEARS:
    if(y!=1990):
        prev_auth = AUTHOR_EVENTS[YEARS.index(y-1)]      
        prev_coll = COLLABORATION_EVENTS[YEARS.index(y-1)]
    num_new_collabs = COLLABORATION_EVENTS[YEARS.index(y)] - prev_coll
    num_new_auths = AUTHOR_EVENTS[YEARS.index(y)] - prev_auth
    ratio = num_new_collabs/num_new_auths
    
    labels.append(str(y) + " -> " + str('{:.2f}'.format(ratio)))
    ratios.append(ratio)

plt.plot(AUTHOR_EVENTS[1:], ratios, color="blue")
    
plt.xticks(AUTHOR_EVENTS[1:], YEARS)
plt.show()

# %%
plt.figure(figsize=(15, 5), dpi=80)
plt.title("Ratio between the total number of collaborations and authors")
plt.xlabel("years")
plt.ylabel("#_collaborations / #_authors")
plt.xticks(rotation=90)


ratios = []
labels = []
for y in YEARS:
    num_new_collabs = COLLABORATION_EVENTS[YEARS.index(y)] 
    num_new_auths = AUTHOR_EVENTS[YEARS.index(y)] 
    ratio = num_new_collabs/num_new_auths
    labels.append(str(y) + " -> " + str('{:.2f}'.format(ratio)))
    ratios.append(ratio)

plt.plot(YEARS, ratios, color="black")
    
plt.xticks(YEARS)
plt.show()

plt.figure(figsize=(15, 5), dpi=80)
plt.title("Ratio between the total number of collaborations and authors stretched by new collaboration event")
plt.xlabel("years stretched by collaborations events")
plt.ylabel("#_collaborations / #_authors")
plt.xticks(rotation=90)

ratios = []
labels = []
for y in YEARS:
    num_new_collabs = COLLABORATION_EVENTS[YEARS.index(y)] 
    num_new_auths = AUTHOR_EVENTS[YEARS.index(y)] 
    ratio = num_new_collabs/num_new_auths
    
    labels.append(str(y) + " -> " + str('{:.2f}'.format(ratio)))
    ratios.append(ratio)

plt.plot(COLLABORATION_EVENTS[1:], ratios, color="orange")
    
plt.xticks(COLLABORATION_EVENTS[1:], YEARS)
plt.show()


plt.figure(figsize=(15, 5), dpi=80)
plt.title("Ratio between the total number of collaborations and authors stretched by new author event")
plt.xlabel("years stretched by author events")
plt.ylabel("#_collaborations / #_authors")
plt.xticks(rotation=90)

ratios = []
labels = []
for y in YEARS:
    num_new_collabs = COLLABORATION_EVENTS[YEARS.index(y)] 
    num_new_auths = AUTHOR_EVENTS[YEARS.index(y)] 
    ratio = num_new_collabs/num_new_auths
    
    labels.append(str(y) + " -> " + str('{:.2f}'.format(ratio)))
    ratios.append(ratio)

plt.plot(AUTHOR_EVENTS[1:], ratios, color="blue")
    
plt.xticks(AUTHOR_EVENTS[1:], YEARS)
plt.show()

# %% [markdown]
# # 2.2.7

# %%
df = get_all_collabs()
df[df["2018"] == 1]
# Out:
#                  ID  1990  1991  1992  1993  1994  1995  1996  1997  1998  \
# 33       6503868852     0     0     0     0     0     0     0     0     0
# 37       6503869410     0     0     0     0     0     0     0     0     0
# 48       6503877574     0     0     0     0     0     0     0     0     0
# 59       6503883197     0     0     0     0     0     0     0     0     0
# 93       6503902541     0     0     0     0     0     0     0     0     0
# ...             ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 232579  57207525701     0     0     0     0     0     0     0     0     0
# 232580  57207526451     0     0     0     0     0     0     0     0     0
# 232669  57207635699     0     0     0     0     0     0     0     0     0
# 232744  57207769369     0     0     0     0     0     0     0     0     0
# 232763  57207805388     0     0     0     0     0     0     0     0     0
#
#         ...  2014  2015  2016  2017  2018  start_year  end_year  \
# 33      ...     1     1     1     1     1        2013      2013
# 37      ...     1     1     1     1     1        2004      2004
# 48      ...     1     1     1     1     1        2000      2000
# 59      ...     1     1     1     1     1        2000      2000
# 93      ...     1     1     1     1     1        2013      2014
# ...     ...   ...   ...   ...   ...   ...         ...       ...
# 232579  ...     1     1     1     1     1        2009      2009
# 232580  ...     0     0     0     0     1        2018      2018
# 232669  ...     1     1     1     1     1        2009      2009
# 232744  ...     0     0     0     0     1        2018      2018
# 232763  ...     0     0     0     0     1        2018      2018
#
#         max_hole_size  activity  tot_pubs
# 33                  0         0         1
# 37                  0         0         1
# 48                  0         0         1
# 59                  0         0         1
# 93                  0         1         2
# ...               ...       ...       ...
# 232579              0         0         1
# 232580              0         0         1
# 232669              0         0         1
# 232744              0         0         1
# 232763              0         0         1
#
# [10943 rows x 35 columns]

# %%
import numpy as np

colls = get_all_collabs()["2018"].values

unique, counts = np.unique(colls, return_counts=True)
    
plt.figure(figsize=(15, 5), dpi=80)
plt.title("Degree distribution (Distribution on the number of collaborations per author)")
plt.xlabel("#_collaborations")
plt.ylabel("#_authors")
plt.xticks(rotation=90)

plt.plot(unique, counts, color="blue")
    
plt.show()

plt.figure(figsize=(15, 5), dpi=80)
plt.title("log-log form of the degree distribution (Distribution on the number of collaborations per author)")
plt.xlabel("log(#_collaborations)")
plt.ylabel("log(#_authors)")
plt.xticks(rotation=90)

plt.plot( np.log(unique), np.log(counts), color="orange")
    
plt.show()

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy.optimize import minimize 

import warnings
warnings.filterwarnings("ignore")

# Import own libraries 
import os, sys
script_path = os.path.realpath(os.path.dirname("10_on_trajectories"))
os.chdir(script_path)
sys.path.append("..")

from myLibraries.queries import * 
from myLibraries.events import *
from myLibraries.theoretical_functions import *
HOLE_SIZE = 7
ACTIVITY = 5
MIN_PUBS = 3
EVENTS = get_collabs_event()
ALL_EVENTS = get_allEvents(EVENTS)

YEARS = get_str_years_event()

# get rid of misleading years
YEARS_TO_CONSIDER = YEARS[1: -6]
EVENTS_TO_CONSIDER = EVENTS[1: -6]
# **Logarithmic Trajectories**
## Plot average trajectories 
plt.figure(figsize=(10, 3), dpi=80)
plt.title("avg trajectory stretched by collaboration events\n", fontdict = {'fontsize' : 12})
plt.xlabel("#new_collaborations as event")
plt.ylabel("#num_collaborations")
plt.xticks(rotation='vertical')

for start_y in YEARS[:-1][10:]:
    x,y = get_avg_trajectories(EVENTS, HOLE_SIZE, start_y, activity=ACTIVITY, minPubs=MIN_PUBS)
    
    if(len(y)==1):
        plt.scatter(x,y)
    else:
        plt.plot(x,y)
    
    plt.xticks(x, y)
    plt.xticks(rotation='vertical')
    break
plt.legend(YEARS[:-1][10:], loc='upper left')
plt.xticks(EVENTS, YEARS)
plt.show()

## Plot fitted average trajectories
plt.figure(figsize=(10, 3), dpi=80)
plt.title("Fitted avg trajectories avg trajectory stretched by collaboration events\n", fontdict = {'fontsize' : 12})
plt.xlabel("#new_collabs as event")
plt.ylabel("#num_Collaborations")
plt.xticks(rotation='vertical')

alphas = []
betas = []
for start_y in YEARS[:-1][10:]:
    
    
    x,y = get_avg_trajectories(EVENTS, HOLE_SIZE, start_y, activity=ACTIVITY, minPubs=MIN_PUBS) # retrieve average trajecory for the given start_y (and hole size)     
    
    fit_y, alpha, beta = fit_trajectory(x, y) # fit the real data above with the theoretical trajectory 
    
    xdata = [a for a in range(x[0], x[-1])]
    fit_y = theoretical_func(xdata, alpha, beta, x[0])

    # save fitted parameters alpha, beta
    alphas.append(alpha)
    betas.append(beta)
        
    plt.plot(x,y, label=str(start_y))
    plt.plot(xdata, fit_y, 'r--')

plt.xticks(rotation='vertical')    
plt.legend(loc='upper left', ncol=2)
plt.xticks(EVENTS, YEARS)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/rorschach/Desktop/INRIA/intership/00_quick_references/15_report_screen.ipynb Cell 1' in <cell line: 63>()
#      <a href='vscode-notebook-cell:/home/rorschach/Desktop/INRIA/intership/00_quick_references/15_report_screen.ipynb#ch0000000?line=62'>63</a> for start_y in YEARS[:-1][10:]:
#      <a href='vscode-notebook-cell:/home/rorschach/Desktop/INRIA/intership/00_quick_references/15_report_screen.ipynb#ch0000000?line=65'>66</a>     x,y = get_avg_trajectories(EVENTS, HOLE_SIZE, start_y, activity=ACTIVITY, minPubs=MIN_PUBS) # retrieve average trajecory for the given start_y (and hole size)
# ---> <a href='vscode-notebook-cell:/home/rorschach/Desktop/INRIA/intership/00_quick_references/15_report_screen.ipynb#ch0000000?line=67'>68</a>     fit_y, alpha, beta = fit_trajectory(x, y) # fit the real data above with the theoretical trajectory
#      <a href='vscode-notebook-cell:/home/rorschach/Desktop/INRIA/intership/00_quick_references/15_report_screen.ipynb#ch0000000?line=69'>70</a>     xdata = [a for a in range(x[0], x[-1])]
#      <a href='vscode-notebook-cell:/home/rorschach/Desktop/INRIA/intership/00_quick_references/15_report_screen.ipynb#ch0000000?line=70'>71</a>     fit_y = theoretical_func(xdata, alpha, beta, x[0])
#
# File ~/Desktop/INRIA/intership/00_quick_references/../myLibraries/theoretical_functions.py:19, in fit_trajectory(xdata, ydata)
#      17 def fit_trajectory(xdata, ydata):
# ---> 19     popt, pcov = curve_fit(lambda x, a, b: theoretical_func(x, a, b, xdata[0]), xdata, ydata, maxfev=5000, bounds=([0, 1], [np.inf, np.inf]))
#      20     alpha = popt[0]
#      21     beta = popt[1]
#
# File ~/anaconda3/envs/intership/lib/python3.9/site-packages/scipy/optimize/minpack.py:735, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     731 # optimization may produce garbage for float32 inputs, cast them to float64
#     732
#     733 # NaNs cannot be handled
#     734 if check_finite:
# --> 735     ydata = np.asarray_chkfinite(ydata, float)
#     736 else:
#     737     ydata = np.asarray(ydata, float)
#
# File ~/anaconda3/envs/intership/lib/python3.9/site-packages/numpy/lib/function_base.py:488, in asarray_chkfinite(a, dtype, order)
#     486 a = asarray(a, dtype=dtype, order=order)
#     487 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 488     raise ValueError(
#     489         "array must not contain infs or NaNs")
#     490 return a
#
# ValueError: array must not contain infs or NaNs

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy.optimize import minimize 

import warnings
warnings.filterwarnings("ignore")

# Import own libraries 
import os, sys
script_path = os.path.realpath(os.path.dirname("10_on_trajectories"))
os.chdir(script_path)
sys.path.append("..")

from myLibraries.queries import * 
from myLibraries.events import *
from myLibraries.theoretical_functions import *
HOLE_SIZE = 7
ACTIVITY = 5
MIN_PUBS = 3
EVENTS = get_auths_event()
ALL_EVENTS = get_allEvents(EVENTS)

YEARS = get_str_years_event()

# get rid of misleading years
YEARS_TO_CONSIDER = YEARS[1: -6]
EVENTS_TO_CONSIDER = EVENTS[1: -6]
# **Logarithmic Trajectories**
## Plot average trajectories 
plt.figure(figsize=(10, 3), dpi=80)
plt.title("avg trajectory stretched by author events\n", fontdict = {'fontsize' : 12})
plt.xlabel("#new_authors as event")
plt.ylabel("#num_collaborations")
plt.xticks(rotation='vertical')

for start_y in YEARS[:-1][10:]:
    x,y = get_avg_trajectories(EVENTS, HOLE_SIZE, start_y, activity=ACTIVITY, minPubs=MIN_PUBS)
    
    if(len(y)==1):
        plt.scatter(x,y)
    else:
        plt.plot(x,y)
    
    plt.xticks(x, y)
    plt.xticks(rotation='vertical')
    break
plt.legend(YEARS[:-1][10:], loc='upper left')
plt.xticks(EVENTS, YEARS)
plt.show()

# %%
plt.figure(figsize=(7, 3), dpi=80)
plt.title("avg trajectory\n", fontdict = {'fontsize' : 12})
plt.xlabel("#new_collabs as event")
plt.ylabel("#num_Collaborations")
plt.xticks(rotation='vertical')

for start_y in YEARS[:-1][10:]:
    x,y = get_avg_trajectories(EVENTS, HOLE_SIZE, start_y, activity=ACTIVITY, minPubs=MIN_PUBS)
    
    x = [int(i) for i in YEARS[10:]]

    
    plt.xticks(rotation='vertical')
    break

plt.plot(x,y, color='black')

plt.legend(YEARS[:-1][10:], loc='upper left')
plt.xticks([int(i) for i in YEARS])
plt.show()

# %% [markdown]
# # **(3)** Find **alpha\* and beta\*** to have a function **f\*** minimizing the **errors**
#
# given a starting event $i$:
# - Let $e$ be a generic event
# - Let $r_i(e)$ be the function representing the real average trajectory for authors who started to publish at the event $i$
# - Let $f_i(e)$ be the fitted function of $r_i(e)$
# - Let $f_i^*(e)$ be the general fitting function of which we want to optimized the parameters, for authors who started to publish at the event $i$
#
# #### A) $min_{\alpha^*,\sigma^*} \Biggl( \sum_i \sum_{e\geq i} |f_i^* (e) - r_i(e) |^2 \Biggr)$
# #### B) $min_{\alpha^*,\sigma^*} \Biggl( \sum_i \max_{e\geq i} |f_i^* (e) - r_i(e) |^2 \Biggr)$
#
# #### C) $min_{\alpha^*,\sigma^*} \Biggl( \sum_i \sum_{e\geq i} |f_i^* (e) - f_i(e) |^2 \Biggr)$
# #### D) $min_{\alpha^*,\sigma^*} \Biggl( \sum_i \max_{e\geq i} |f_i^* (e) - f_i(e) |^2 \Biggr)$

# %% [markdown]
# # **(3)** Find **alpha\* and beta\*** to have a function **f\*** minimizing the **errors**
#
# given a starting event $i$:
# - Let $t$ be a generic event
# - Let $r_{t_v}(t)$ be the function representing the real average trajectory for authors who started to publish at the event $t_v$
# - Let $d_{t_v}(t)$ be the fitted function of $r_{t_v}(t)$
# - Let $f_{t_v}^*(t)$ be the general fitting function of which we want to optimized the parameters, for authors who started to publish at the event ${t_v}$
#
# #### A) $min_{\alpha^*,\beta^*} \Biggl( \sum_{t_v} \sum_{t\geq t_v} |d_{t_v}(t)^* - r_{t_v}(t) |^2 \Biggr)$
# #### B) $min_{\alpha^*,\beta^*} \Biggl( \sum_{t_v} \max_{t\geq t_v} |d_{t_v}(t)^* - r_{t_v}(t) |^2 \Biggr)$
# #### C) $min_{\alpha^*,\beta^*} \Biggl( \sum_{t_v} \sum_{t\geq t_v} |d_{t_v}(t)^* - d_{t_v}(t) |^2 \Biggr)$
# #### D) $min_{\alpha^*,\beta^*} \Biggl( \sum_{t_v} \max_{t\geq t_v} |d_{t_v}(t)^* - d_{t_v}(t) |^2 \Biggr)$

# %%
# Out:
#   Input In [2]
#     given a starting event $i$:
#           ^
# SyntaxError: invalid syntax
